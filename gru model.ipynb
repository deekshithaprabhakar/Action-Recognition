# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

# %%
# Define paths and actions
actions = np.array(['MoveRight', 'MoveLeft', 'ThumbsUp', 'ThumbsDown', 'Stop', 'Circle', 'FistClose', 'Victory'])
data_path = "/kaggle/input/hand-gesture-recogniton/Action_Recognition" 
no_sequences = 100
sequence_length = 60
features = 1662  # Adjust this based on the actual features per frame
num_classes = len(actions)

# %%
print(f"Actions: {actions}")
print(f"Number of classes: {num_classes}")
print(f"Data path: {data_path}")
# Out:
# Actions: ['MoveRight' 'MoveLeft' 'ThumbsUp' 'ThumbsDown' 'Stop' 'Circle'
#  'FistClose' 'Victory']
# Number of classes: 8
# Data path: /kaggle/input/hand-gesture-recogniton/Action_Recognition

# %%
# Map each action to an integer
label_map = {label: num for num, label in enumerate(actions)}
print("Label map:", label_map)
# Out:
# Label map: {'MoveRight': 0, 'MoveLeft': 1, 'ThumbsUp': 2, 'ThumbsDown': 3, 'Stop': 4, 'Circle': 5, 'FistClose': 6, 'Victory': 7}

# %%
# Load data
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame_path = os.path.join(data_path, action, str(sequence), f"{frame_num}.npy")
            res = np.load(frame_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
    print(f"Loaded data for action: {action}")
# Out:
# Loaded data for action: MoveRight
# Loaded data for action: MoveLeft
# Loaded data for action: ThumbsUp
# Loaded data for action: ThumbsDown
# Loaded data for action: Stop
# Loaded data for action: Circle
# Loaded data for action: FistClose
# Loaded data for action: Victory

# %%
# Convert labels to one-hot encoding and lists to numpy arrays
labels = to_categorical(labels, num_classes=num_classes)
sequences = np.array(sequences)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.05, random_state=42)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (760, 60, 1662), X_test shape: (40, 60, 1662)
# y_train shape: (760, 8), y_test shape: (40, 8)

# %%
# Build the model
model = Sequential()
model.add(GRU(64, return_sequences = True, activation = 'relu', input_shape = (60,1662)))
model.add(GRU(256, return_sequences = True, activation = 'relu'))
model.add(GRU(128, return_sequences = True, activation = 'relu'))
model.add(GRU(64, return_sequences = False, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(actions.shape[0], activation = 'softmax'))
print("Model has been built.")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model has been built.

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print("Model compilation complete.")
# Out:
# Model compilation complete.

# %%
# Callbacks
tb_callback = TensorBoard(log_dir='./logs', update_freq='batch')
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
print("Callbacks have been set.")
# Out:
# Callbacks have been set.

# %%
# Train the model
print("Starting model training...")
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=200, callbacks=[early_stopping, tb_callback])
print("Model training complete.")
# Out:
# Starting model training...
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717259368.892676     136 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1717259368.963198     136 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - categorical_accuracy: 0.1460 - loss: 2.0809 - val_categorical_accuracy: 0.0500 - val_loss: 2.0870
# Epoch 2/200
#  3/24 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.1267 - loss: 2.0786
# W0000 00:00:1717259378.108463     136 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.1591 - loss: 2.0784 - val_categorical_accuracy: 0.0500 - val_loss: 2.0856
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.1578 - loss: 2.0782 - val_categorical_accuracy: 0.0500 - val_loss: 2.0906
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.1276 - loss: 2.0782 - val_categorical_accuracy: 0.0500 - val_loss: 2.0949
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.1439 - loss: 2.0754 - val_categorical_accuracy: 0.0500 - val_loss: 2.0963
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.1531 - loss: 2.0748 - val_categorical_accuracy: 0.0500 - val_loss: 2.1001
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.1867 - loss: 2.0645 - val_categorical_accuracy: 0.2000 - val_loss: 2.0670
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2268 - loss: 2.0316 - val_categorical_accuracy: 0.3000 - val_loss: 2.0049
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2208 - loss: 2.0070 - val_categorical_accuracy: 0.2000 - val_loss: 2.0271
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2620 - loss: 1.9584 - val_categorical_accuracy: 0.3000 - val_loss: 1.9074
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2833 - loss: 1.9003 - val_categorical_accuracy: 0.3000 - val_loss: 1.9866
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2744 - loss: 1.8857 - val_categorical_accuracy: 0.2000 - val_loss: 1.8686
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2506 - loss: 1.8985 - val_categorical_accuracy: 0.3250 - val_loss: 1.8313
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2814 - loss: 1.8449 - val_categorical_accuracy: 0.3500 - val_loss: 1.8072
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3141 - loss: 1.8308 - val_categorical_accuracy: 0.3250 - val_loss: 1.7063
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3363 - loss: 1.7466 - val_categorical_accuracy: 0.3750 - val_loss: 1.7014
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3564 - loss: 1.7312 - val_categorical_accuracy: 0.2250 - val_loss: 1.7962
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.2716 - loss: 1.7956 - val_categorical_accuracy: 0.3750 - val_loss: 1.6736
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3339 - loss: 1.7444 - val_categorical_accuracy: 0.3250 - val_loss: 1.7210
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3523 - loss: 1.7246 - val_categorical_accuracy: 0.2500 - val_loss: 1.7729
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.2876 - loss: 1.8246 - val_categorical_accuracy: 0.3250 - val_loss: 1.6810
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3283 - loss: 1.7473 - val_categorical_accuracy: 0.4000 - val_loss: 1.6174
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3205 - loss: 1.6883 - val_categorical_accuracy: 0.2750 - val_loss: 1.5761
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.3707 - loss: 1.6404 - val_categorical_accuracy: 0.3500 - val_loss: 1.5337
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4178 - loss: 1.6039 - val_categorical_accuracy: 0.3250 - val_loss: 1.5395
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3272 - loss: 1.6426 - val_categorical_accuracy: 0.3500 - val_loss: 1.5209
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4123 - loss: 1.5628 - val_categorical_accuracy: 0.3750 - val_loss: 1.5240
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - categorical_accuracy: 0.4048 - loss: 1.6001 - val_categorical_accuracy: 0.3500 - val_loss: 1.5139
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - categorical_accuracy: 0.3654 - loss: 1.5821 - val_categorical_accuracy: 0.3750 - val_loss: 1.4887
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.3929 - loss: 1.5744 - val_categorical_accuracy: 0.3500 - val_loss: 1.5504
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.3714 - loss: 1.5769 - val_categorical_accuracy: 0.4250 - val_loss: 1.4583
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4116 - loss: 1.4958 - val_categorical_accuracy: 0.3250 - val_loss: 1.4895
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.3862 - loss: 1.5173 - val_categorical_accuracy: 0.3000 - val_loss: 1.4935
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3680 - loss: 1.5852 - val_categorical_accuracy: 0.3000 - val_loss: 1.6587
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3472 - loss: 1.6162 - val_categorical_accuracy: 0.3000 - val_loss: 1.5064
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3732 - loss: 1.5835 - val_categorical_accuracy: 0.4000 - val_loss: 1.4340
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3936 - loss: 1.5329 - val_categorical_accuracy: 0.4250 - val_loss: 1.4271
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3911 - loss: 1.5525 - val_categorical_accuracy: 0.3250 - val_loss: 1.4251
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4107 - loss: 1.4765 - val_categorical_accuracy: 0.3500 - val_loss: 1.5028
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3927 - loss: 1.5054 - val_categorical_accuracy: 0.3750 - val_loss: 1.4086
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3809 - loss: 1.5335 - val_categorical_accuracy: 0.3250 - val_loss: 1.4162
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3956 - loss: 1.4989 - val_categorical_accuracy: 0.3250 - val_loss: 1.5799
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4013 - loss: 1.5538 - val_categorical_accuracy: 0.4000 - val_loss: 1.4289
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3739 - loss: 1.5803 - val_categorical_accuracy: 0.4250 - val_loss: 1.5262
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3830 - loss: 1.5025 - val_categorical_accuracy: 0.4000 - val_loss: 1.3968
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4313 - loss: 1.4592 - val_categorical_accuracy: 0.4000 - val_loss: 1.3885
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.4247 - loss: 1.4457 - val_categorical_accuracy: 0.3500 - val_loss: 1.3924
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.4372 - loss: 1.4813 - val_categorical_accuracy: 0.4000 - val_loss: 1.4324
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4628 - loss: 1.3963 - val_categorical_accuracy: 0.3750 - val_loss: 1.3674
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4363 - loss: 1.4321 - val_categorical_accuracy: 0.3500 - val_loss: 1.4043
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.4175 - loss: 1.4667 - val_categorical_accuracy: 0.4500 - val_loss: 1.3415
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.4276 - loss: 1.4699 - val_categorical_accuracy: 0.3750 - val_loss: 1.3557
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.4631 - loss: 1.4239 - val_categorical_accuracy: 0.3250 - val_loss: 1.5913
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4612 - loss: 1.3912 - val_categorical_accuracy: 0.5000 - val_loss: 1.3841
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4383 - loss: 1.4239 - val_categorical_accuracy: 0.3750 - val_loss: 1.5737
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.3811 - loss: 1.5467 - val_categorical_accuracy: 0.4750 - val_loss: 1.3429
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4289 - loss: 1.4011 - val_categorical_accuracy: 0.4250 - val_loss: 1.3934
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4440 - loss: 1.4149 - val_categorical_accuracy: 0.4750 - val_loss: 1.4186
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4168 - loss: 1.4350 - val_categorical_accuracy: 0.3500 - val_loss: 1.3088
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.4797 - loss: 1.3345 - val_categorical_accuracy: 0.4250 - val_loss: 1.3841
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - categorical_accuracy: 0.4911 - loss: 1.3495 - val_categorical_accuracy: 0.4000 - val_loss: 1.2613
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.4187 - loss: 1.4071 - val_categorical_accuracy: 0.4750 - val_loss: 1.2545
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4961 - loss: 1.3490 - val_categorical_accuracy: 0.5250 - val_loss: 1.2835
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4861 - loss: 1.3390 - val_categorical_accuracy: 0.4000 - val_loss: 1.2930
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4543 - loss: 1.3348 - val_categorical_accuracy: 0.5250 - val_loss: 1.2420
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4977 - loss: 1.3230 - val_categorical_accuracy: 0.4250 - val_loss: 1.1963
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4761 - loss: 1.3307 - val_categorical_accuracy: 0.5750 - val_loss: 1.3347
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.4905 - loss: 1.2844 - val_categorical_accuracy: 0.5250 - val_loss: 1.1925
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.5429 - loss: 1.2305 - val_categorical_accuracy: 0.6250 - val_loss: 1.1391
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5046 - loss: 1.2871 - val_categorical_accuracy: 0.4500 - val_loss: 1.2455
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5020 - loss: 1.2731 - val_categorical_accuracy: 0.6750 - val_loss: 1.1300
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5006 - loss: 1.2817 - val_categorical_accuracy: 0.4500 - val_loss: 1.1979
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5231 - loss: 1.2189 - val_categorical_accuracy: 0.5250 - val_loss: 1.2256
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5373 - loss: 1.1968 - val_categorical_accuracy: 0.5750 - val_loss: 1.0768
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.5374 - loss: 1.2287 - val_categorical_accuracy: 0.5500 - val_loss: 1.1448
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5664 - loss: 1.1973 - val_categorical_accuracy: 0.5000 - val_loss: 1.3657
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5424 - loss: 1.2060 - val_categorical_accuracy: 0.5500 - val_loss: 1.0868
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5041 - loss: 1.3024 - val_categorical_accuracy: 0.5000 - val_loss: 1.1324
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5527 - loss: 1.2077 - val_categorical_accuracy: 0.5750 - val_loss: 1.1024
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5683 - loss: 1.1296 - val_categorical_accuracy: 0.5750 - val_loss: 1.1106
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5348 - loss: 1.1376 - val_categorical_accuracy: 0.6250 - val_loss: 1.0229
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5540 - loss: 1.1802 - val_categorical_accuracy: 0.5000 - val_loss: 1.0732
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5458 - loss: 1.2204 - val_categorical_accuracy: 0.6250 - val_loss: 1.0229
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5533 - loss: 1.1738 - val_categorical_accuracy: 0.5250 - val_loss: 1.4008
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.5201 - loss: 1.1940 - val_categorical_accuracy: 0.3750 - val_loss: 1.1802
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5507 - loss: 1.1656 - val_categorical_accuracy: 0.5500 - val_loss: 1.0780
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5610 - loss: 1.1166 - val_categorical_accuracy: 0.5500 - val_loss: 1.0439
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5553 - loss: 1.1173 - val_categorical_accuracy: 0.6250 - val_loss: 1.0342
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5963 - loss: 1.1108 - val_categorical_accuracy: 0.5000 - val_loss: 1.0857
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5586 - loss: 1.1606 - val_categorical_accuracy: 0.5750 - val_loss: 1.0428
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5904 - loss: 1.0418 - val_categorical_accuracy: 0.6750 - val_loss: 0.9433
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6117 - loss: 1.0347 - val_categorical_accuracy: 0.6500 - val_loss: 1.0763
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - categorical_accuracy: 0.5539 - loss: 1.1042 - val_categorical_accuracy: 0.6000 - val_loss: 0.9986
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5821 - loss: 1.1020 - val_categorical_accuracy: 0.6750 - val_loss: 0.9965
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5960 - loss: 1.0567 - val_categorical_accuracy: 0.5500 - val_loss: 1.0975
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6333 - loss: 0.9880 - val_categorical_accuracy: 0.6750 - val_loss: 0.9863
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6436 - loss: 1.0044 - val_categorical_accuracy: 0.5500 - val_loss: 0.9975
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5754 - loss: 1.1147 - val_categorical_accuracy: 0.6000 - val_loss: 1.0070
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.5902 - loss: 1.0313 - val_categorical_accuracy: 0.6250 - val_loss: 0.9317
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.5783 - loss: 1.0356 - val_categorical_accuracy: 0.6500 - val_loss: 1.0632
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6298 - loss: 1.0031 - val_categorical_accuracy: 0.6750 - val_loss: 0.9387
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6241 - loss: 0.9767 - val_categorical_accuracy: 0.6500 - val_loss: 0.9514
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.6368 - loss: 0.9499 - val_categorical_accuracy: 0.6750 - val_loss: 0.9130
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6676 - loss: 0.9314 - val_categorical_accuracy: 0.6250 - val_loss: 1.0161
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6380 - loss: 0.8959 - val_categorical_accuracy: 0.5750 - val_loss: 1.2104
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6450 - loss: 0.9480 - val_categorical_accuracy: 0.5250 - val_loss: 1.0245
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6503 - loss: 0.8637 - val_categorical_accuracy: 0.6000 - val_loss: 0.8991
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6274 - loss: 0.9193 - val_categorical_accuracy: 0.6250 - val_loss: 0.9954
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.5810 - loss: 1.0165 - val_categorical_accuracy: 0.5500 - val_loss: 0.9884
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6426 - loss: 0.9357 - val_categorical_accuracy: 0.6250 - val_loss: 1.1095
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6205 - loss: 1.0037 - val_categorical_accuracy: 0.6250 - val_loss: 0.9027
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6458 - loss: 0.8693 - val_categorical_accuracy: 0.7000 - val_loss: 0.8718
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.6062 - loss: 0.9730 - val_categorical_accuracy: 0.6750 - val_loss: 0.8526
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6512 - loss: 0.8746 - val_categorical_accuracy: 0.6750 - val_loss: 0.9076
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6232 - loss: 0.9156 - val_categorical_accuracy: 0.6000 - val_loss: 0.9496
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6404 - loss: 0.8976 - val_categorical_accuracy: 0.6250 - val_loss: 1.2602
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6153 - loss: 1.0079 - val_categorical_accuracy: 0.5250 - val_loss: 1.1766
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7037 - loss: 0.8592 - val_categorical_accuracy: 0.5250 - val_loss: 1.4343
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6191 - loss: 1.0097 - val_categorical_accuracy: 0.6750 - val_loss: 0.8964
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7001 - loss: 0.8252 - val_categorical_accuracy: 0.6000 - val_loss: 1.1424
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6513 - loss: 0.9068 - val_categorical_accuracy: 0.5250 - val_loss: 1.4185
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6270 - loss: 0.9368 - val_categorical_accuracy: 0.6000 - val_loss: 1.1477
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6602 - loss: 0.8353 - val_categorical_accuracy: 0.6000 - val_loss: 0.8799
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - categorical_accuracy: 0.6833 - loss: 0.8324 - val_categorical_accuracy: 0.7000 - val_loss: 0.8329
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - categorical_accuracy: 0.7090 - loss: 0.8202 - val_categorical_accuracy: 0.6500 - val_loss: 0.8257
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6621 - loss: 0.8391 - val_categorical_accuracy: 0.7000 - val_loss: 0.9057
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6920 - loss: 0.7523 - val_categorical_accuracy: 0.6250 - val_loss: 0.8750
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6700 - loss: 0.7489 - val_categorical_accuracy: 0.6000 - val_loss: 0.9845
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7267 - loss: 0.6853 - val_categorical_accuracy: 0.7000 - val_loss: 0.7634
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6642 - loss: 0.8418 - val_categorical_accuracy: 0.6750 - val_loss: 0.9785
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6781 - loss: 0.8383 - val_categorical_accuracy: 0.6000 - val_loss: 0.9012
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6797 - loss: 0.7887 - val_categorical_accuracy: 0.7000 - val_loss: 0.9265
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6922 - loss: 0.7641 - val_categorical_accuracy: 0.6750 - val_loss: 0.7793
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7148 - loss: 0.7458 - val_categorical_accuracy: 0.6750 - val_loss: 0.8201
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7302 - loss: 0.7261 - val_categorical_accuracy: 0.6250 - val_loss: 0.8580
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7007 - loss: 0.7578 - val_categorical_accuracy: 0.6250 - val_loss: 1.1246
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7387 - loss: 0.6715 - val_categorical_accuracy: 0.6500 - val_loss: 0.9996
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7423 - loss: 0.6586 - val_categorical_accuracy: 0.7000 - val_loss: 0.7953
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.7235 - loss: 0.7474 - val_categorical_accuracy: 0.5750 - val_loss: 1.2296
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6884 - loss: 0.8023 - val_categorical_accuracy: 0.7500 - val_loss: 0.7728
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7628 - loss: 0.6238 - val_categorical_accuracy: 0.7500 - val_loss: 0.8587
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7383 - loss: 0.6936 - val_categorical_accuracy: 0.6000 - val_loss: 1.0578
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7399 - loss: 0.6525 - val_categorical_accuracy: 0.6750 - val_loss: 1.1451
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7300 - loss: 0.6664 - val_categorical_accuracy: 0.6750 - val_loss: 0.9309
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7686 - loss: 0.5734 - val_categorical_accuracy: 0.6500 - val_loss: 0.8279
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7642 - loss: 0.6131 - val_categorical_accuracy: 0.7000 - val_loss: 0.9869
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - categorical_accuracy: 0.6465 - loss: 0.9049 - val_categorical_accuracy: 0.6750 - val_loss: 0.8141
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.6796 - loss: 0.7949 - val_categorical_accuracy: 0.6500 - val_loss: 1.0476
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - categorical_accuracy: 0.7622 - loss: 0.6297 - val_categorical_accuracy: 0.6500 - val_loss: 0.8667
# Model training complete.

# %%
# Prediction
print("Starting prediction...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print("Prediction complete.")
# Out:
# Starting prediction...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Prediction complete.

# %%
# Evaluation
accuracy = accuracy_score(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.7
# F1 Score: 0.6821284271284271

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 5
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# W0000 00:00:1717259596.348590     136 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [5 4 0 3 2]
# Actual labels (class indices): [6 4 0 3 2]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 8
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [0 6 2 3 5 0 2 0]
# Actual labels (class indices): [0 6 7 7 5 0 4 0]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
print("Predicted actions:", predicted_actions)
print("Actual actions:", actual_actions)
# Out:
# Predicted actions: ['MoveRight', 'FistClose', 'ThumbsUp', 'ThumbsDown', 'Circle', 'MoveRight', 'ThumbsUp', 'MoveRight']
# Actual actions: ['MoveRight', 'FistClose', 'Victory', 'Victory', 'Circle', 'MoveRight', 'Stop', 'MoveRight']
