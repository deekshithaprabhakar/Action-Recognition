# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, LSTM, Dense,idirectional, Dropout, Bidirectional, MaxPooling3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
# Out:
# 2024-06-01 15:12:42.826680: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-01 15:12:42.826794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-01 15:12:42.992333: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Define paths and actions
actions = np.array(['MoveRight', 'MoveLeft', 'ThumbsUp', 'ThumbsDown', 'Stop', 'Circle', 'FistClose', 'Victory'])
data_path = "/kaggle/input/hand-gesture-recogniton/Action_Recognition" 
no_sequences = 100
sequence_length = 60
featudjust this based on the actual features per frame
num_classes = len(actions)

# %%
print(f"Actions: {actions}")
print(f"Number of classes: {num_classes}")
print(f"Data path: {data_path}")
# Out:
# Actions: ['MoveRight' 'MoveLeft' 'ThumbsUp' 'ThumbsDown' 'Stop' 'Circle'
#  'FistClose' 'Victory']
# Number of classes: 8
# Data path: /kaggle/input/hand-gesture-recogniton/Action_Recognition

# %%
# Map each action to an integer
label_map = {label: num for num, label in enumerate(actions)}
print("Label map:", label_map)
# Out:
# Label map: {'MoveRight': 0, 'MoveLeft': 1, 'ThumbsUp': 2, 'ThumbsDown': 3, 'Stop': 4, 'Circle': 5, 'FistClose': 6, 'Victory': 7}

# %%
import os
# Load data
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame_path = os.path.join(data_path, action, str(sequence), f"{frame_num}.npy")
            res = np.load(frame_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
    print(f"Loaded data for action: {action}")
# Out:
# Loaded data for action: MoveRight
# Loaded data for action: MoveLeft
# Loaded data for action: ThumbsUp
# Loaded data for action: ThumbsDown
# Loaded data for action: Stop
# Loaded data for action: Circle
# Loaded data for action: FistClose
# Loaded data for action: Victory

# %%
# Convert labels to one-hot encoding and lists to numpy arrays
labels = to_categorical(labels, num_classes=num_classes)
sequences = np.array(sequences)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.05, random_state=42)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (760, 60, 1662), X_test shape: (40, 60, 1662)
# y_train shape: (760, 8), y_test shape: (40, 8)

# %%
model = Sequential()

model.add(Reshape((60, 1, 1662, 1), input_shape=(60, 1662, 1)))

# 3D Convolutional layers
model.add(Conv3D(filters=64, kernel_size=(3, 1, 3), activation='relu', padding='same', input_shape=(60, 1, 1662, 1)))
model.add(MaxPooling3D(pool_size=(2, 1, 2)))
model.add(Dropout(0.5))

model.add(Conv3D(filters=64, kernel_size=(3, 1, 3), activation='relu', padding='same'))
model.add(MaxPooling3D(pool_size=(2, 1, 2)))
model.add(Conv3D(filters=128, kernel_size=(3, 1, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(TimeDistributed(Flatten()))

# LSTM layers to capture temporal dependencies
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.5))

# Fully connected layers
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, activation='softmax'))
print("Model has been built.")
# Out:
# Model has been built.

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print("Model compilation complete.")
# Out:
# Model compilation complete.

# %%
# Callbacks
tb_callback = TensorBoard(log_dir='./logs', update_freq='batch')
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
print("Callbacks have been set.")
# Out:
# Callbacks have been set.

# %%
# Train the model
print("Starting model training...")
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=100, callbacks=[early_stopping, tb_callback])
print("Model training complete.")
# Out:
# Starting model training...
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 29s 678ms/step - categorical_accuracy: 0.1160 - loss: 2.1219 - val_categorical_accuracy: 0.1000 - val_loss: 2.0859
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 406ms/step - categorical_accuracy: 0.1174 - loss: 2.0898 - val_categorical_accuracy: 0.1750 - val_loss: 2.0772
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 397ms/step - categorical_accuracy: 0.1248 - loss: 2.0780 - val_categorical_accuracy: 0.2250 - val_loss: 2.0779
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - categorical_accuracy: 0.1545 - loss: 2.0774 - val_categorical_accuracy: 0.0500 - val_loss: 2.0796
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 406ms/step - categorical_accuracy: 0.1287 - loss: 2.0770 - val_categorical_accuracy: 0.0500 - val_loss: 2.0793
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 411ms/step - categorical_accuracy: 0.1512 - loss: 2.0749 - val_categorical_accuracy: 0.0750 - val_loss: 2.0780
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 428ms/step - categorical_accuracy: 0.1213 - loss: 2.0715 - val_categorical_accuracy: 0.1750 - val_loss: 2.0457
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - categorical_accuracy: 0.1736 - loss: 2.0429 - val_categorical_accuracy: 0.1750 - val_loss: 2.0205
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 438ms/step - categorical_accuracy: 0.2423 - loss: 1.9947 - val_categorical_accuracy: 0.2250 - val_loss: 1.9006
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 430ms/step - categorical_accuracy: 0.2035 - loss: 1.9841 - val_categorical_accuracy: 0.2500 - val_loss: 1.9094
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 426ms/step - categorical_accuracy: 0.2493 - loss: 1.9684 - val_categorical_accuracy: 0.1750 - val_loss: 1.9547
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - categorical_accuracy: 0.2899 - loss: 1.8714 - val_categorical_accuracy: 0.3500 - val_loss: 1.7606
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 421ms/step - categorical_accuracy: 0.3100 - loss: 1.7658 - val_categorical_accuracy: 0.2000 - val_loss: 1.9347
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - categorical_accuracy: 0.3802 - loss: 1.6750 - val_categorical_accuracy: 0.3750 - val_loss: 1.6741
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 421ms/step - categorical_accuracy: 0.3524 - loss: 1.6440 - val_categorical_accuracy: 0.3250 - val_loss: 1.7537
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.3948 - loss: 1.5886 - val_categorical_accuracy: 0.2750 - val_loss: 1.7756
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 437ms/step - categorical_accuracy: 0.4202 - loss: 1.5269 - val_categorical_accuracy: 0.3250 - val_loss: 1.6512
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.4699 - loss: 1.4714 - val_categorical_accuracy: 0.3500 - val_loss: 1.7369
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.4667 - loss: 1.4231 - val_categorical_accuracy: 0.4000 - val_loss: 1.5724
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - categorical_accuracy: 0.5046 - loss: 1.3743 - val_categorical_accuracy: 0.3750 - val_loss: 1.5008
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0.5130 - loss: 1.2983 - val_categorical_accuracy: 0.4000 - val_loss: 1.5575
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - categorical_accuracy: 0.5554 - loss: 1.2665 - val_categorical_accuracy: 0.4750 - val_loss: 1.3529
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.5283 - loss: 1.3144 - val_categorical_accuracy: 0.4500 - val_loss: 1.3838
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.5266 - loss: 1.2795 - val_categorical_accuracy: 0.3750 - val_loss: 1.3296
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.5372 - loss: 1.2043 - val_categorical_accuracy: 0.6250 - val_loss: 1.0834
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.5657 - loss: 1.1799 - val_categorical_accuracy: 0.5500 - val_loss: 1.2714
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.6329 - loss: 1.1302 - val_categorical_accuracy: 0.5000 - val_loss: 1.3451
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0.6227 - loss: 1.0754 - val_categorical_accuracy: 0.6000 - val_loss: 1.1401
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.5798 - loss: 1.1106 - val_categorical_accuracy: 0.7000 - val_loss: 1.0605
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - categorical_accuracy: 0.6152 - loss: 1.0548 - val_categorical_accuracy: 0.6750 - val_loss: 0.9812
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.7712 - loss: 0.6494 - val_categorical_accuracy: 0.6000 - val_loss: 1.1498
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.7419 - loss: 0.6631 - val_categorical_accuracy: 0.7250 - val_loss: 0.8094
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - categorical_accuracy: 0.8159 - loss: 0.5400 - val_categorical_accuracy: 0.7250 - val_loss: 0.7436
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8207 - loss: 0.5401 - val_categorical_accuracy: 0.7250 - val_loss: 0.8565
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8471 - loss: 0.5059 - val_categorical_accuracy: 0.8000 - val_loss: 0.8405
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8546 - loss: 0.4431 - val_categorical_accuracy: 0.6250 - val_loss: 1.0489
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8139 - loss: 0.4977 - val_categorical_accuracy: 0.7000 - val_loss: 0.8189
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8386 - loss: 0.4700 - val_categorical_accuracy: 0.8000 - val_loss: 0.8024
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0.8466 - loss: 0.4419 - val_categorical_accuracy: 0.7500 - val_loss: 0.7569
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.8601 - loss: 0.4166 - val_categorical_accuracy: 0.7250 - val_loss: 0.9116
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.8655 - loss: 0.4379 - val_categorical_accuracy: 0.7250 - val_loss: 0.8369
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8440 - loss: 0.4516 - val_categorical_accuracy: 0.6250 - val_loss: 0.9543
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.8597 - loss: 0.4241 - val_categorical_accuracy: 0.7250 - val_loss: 1.0097
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8449 - loss: 0.4637 - val_categorical_accuracy: 0.6500 - val_loss: 0.9821
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - categorical_accuracy: 0.8192 - loss: 0.5014 - val_categorical_accuracy: 0.5750 - val_loss: 1.2138
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8499 - loss: 0.4556 - val_categorical_accuracy: 0.7500 - val_loss: 0.8661
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8403 - loss: 0.4238 - val_categorical_accuracy: 0.6500 - val_loss: 1.1352
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0.8716 - loss: 0.3961 - val_categorical_accuracy: 0.7250 - val_loss: 0.7933
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8615 - loss: 0.3830 - val_categorical_accuracy: 0.7250 - val_loss: 0.9300
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.8917 - loss: 0.3427 - val_categorical_accuracy: 0.6750 - val_loss: 0.9904
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 424ms/step - categorical_accuracy: 0.9117 - loss: 0.2908 - val_categorical_accuracy: 0.7000 - val_loss: 0.8980
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - categorical_accuracy: 0.8933 - loss: 0.3171 - val_categorical_accuracy: 0.6250 - val_loss: 1.0394
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 430ms/step - categorical_accuracy: 0.8866 - loss: 0.3925 - val_categorical_accuracy: 0.6000 - val_loss: 1.2855
# Model training complete.

# %%
# Prediction
print("Starting prediction...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print("Prediction complete.")
# Out:
# Starting prediction...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Prediction complete.

# %%
# Evaluation
accuracy = accuracy_score(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.725
# F1 Score: 0.7039661319073084

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 5
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 3 7 2 0]
# Actual labels (class indices): [6 3 6 2 0]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 8
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [2 4 3 2 5 7 3 7]
# Actual labels (class indices): [2 6 3 7 5 6 3 6]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
print("Predicted actions:", predicted_actions)
print("Actual actions:", actual_actions)
# Out:
# Predicted actions: ['ThumbsUp', 'Stop', 'ThumbsDown', 'ThumbsUp', 'Circle', 'Victory', 'ThumbsDown', 'Victory']
# Actual actions: ['ThumbsUp', 'FistClose', 'ThumbsDown', 'Victory', 'Circle', 'FistClose', 'ThumbsDown', 'FistClose']
