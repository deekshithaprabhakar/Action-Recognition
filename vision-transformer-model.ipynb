# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from transformers import ViTModel
# Out:
# 2024-06-01 15:45:31.590728: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-01 15:45:31.590818: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-01 15:45:31.733944: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Define paths and actions
actions = np.array(['MoveRight', 'MoveLeft', 'ThumbsUp', 'ThumbsDown', 'Stop', 'Circle', 'FistClose', 'Victory'])
data_path = "/kaggle/input/hand-gesture-recogniton/Action_Recognition" 
no_sequences = 100
sequence_length = 60
features = 1662  # Adjust this based on the actual features per frame
num_classes = len(actions)

# %%
print(f"Actions: {actions}")
print(f"Number of classes: {num_classes}")
print(f"Data path: {data_path}")
# Out:
# Actions: ['MoveRight' 'MoveLeft' 'ThumbsUp' 'ThumbsDown' 'Stop' 'Circle'
#  'FistClose' 'Victory']
# Number of classes: 8
# Data path: /kaggle/input/hand-gesture-recogniton/Action_Recognition

# %%
# Map each action to an integer
label_map = {label: num for num, label in enumerate(actions)}
print("Label map:", label_map)
# Out:
# Label map: {'MoveRight': 0, 'MoveLeft': 1, 'ThumbsUp': 2, 'ThumbsDown': 3, 'Stop': 4, 'Circle': 5, 'FistClose': 6, 'Victory': 7}

# %%
import os
# Load data
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame_path = os.path.join(data_path, action, str(sequence), f"{frame_num}.npy")
            res = np.load(frame_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
    print(f"Loaded data for action: {action}")
# Out:
# Loaded data for action: MoveRight
# Loaded data for action: MoveLeft
# Loaded data for action: ThumbsUp
# Loaded data for action: ThumbsDown
# Loaded data for action: Stop
# Loaded data for action: Circle
# Loaded data for action: FistClose
# Loaded data for action: Victory

# %%
# Convert labels to one-hot encoding and lists to numpy arrays
labels = to_categorical(labels, num_classes=num_classes)
sequences = np.array(sequences)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.05, random_state=42)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (760, 60, 1662), X_test shape: (40, 60, 1662)
# y_train shape: (760, 8), y_test shape: (40, 8)

# %%
def transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    # Add positional encoding
    position_encoding = layers.Embedding(input_dim=input_shape[0], output_dim=input_shape[1])(tf.range(start=0, limit=input_shape[0], delta=1))
    encoded_inputs = inputs + position_encoding

    # Transformer Encoder layers
    for _ in range(4):
        # Multi-head self-attention
        attention_output = layers.MultiHeadAttention(num_heads=8, key_dim=64)(encoded_inputs, encoded_inputs)
        # Add & Norm
        attention_output = layers.Add()([encoded_inputs, attention_output])
        attention_output = layers.LayerNormalization(epsilon=1e-6)(attention_output)
        # Feed forward
        feed_forward = layers.Dense(units=512, activation='relu')(attention_output)
        feed_forward = layers.Dense(units=input_shape[-1])(feed_forward)
        # Add & Norm
        encoded_inputs = layers.Add()([attention_output, feed_forward])
        encoded_inputs = layers.LayerNormalization(epsilon=1e-6)(encoded_inputs)

    # Global average pooling
    pooled_output = layers.GlobalAveragePooling1D()(encoded_inputs)
    # Output layer
    outputs = layers.Dense(units=8, activation='softmax')(pooled_output)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Instantiate the model
model = transformer_model(input_shape=X_train.shape[1:], num_classes=len(np.unique(y_train)))

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print("Model compilation complete.")
# Out:
# Model compilation complete.

# %%
# Callbacks
tb_callback = TensorBoard(log_dir='./logs', update_freq='batch')
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
print("Callbacks have been set.")
# Out:
# Callbacks have been set.

# %%
# Train the model
print("Starting model training...")
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=100, callbacks=[early_stopping, tb_callback])
print("Model training complete.")
# Out:
# Starting model training...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717257536.007914     151 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1717257536.035740     151 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - categorical_accuracy: 0.1305 - loss: 4.1478
# W0000 00:00:1717257545.279389     149 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1717257546.982352     149 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1717257548.192506     152 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 28s 525ms/step - categorical_accuracy: 0.1321 - loss: 4.1172 - val_categorical_accuracy: 0.2250 - val_loss: 2.3050
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.2688 - loss: 1.9658 - val_categorical_accuracy: 0.2750 - val_loss: 1.5214
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.4414 - loss: 1.5305 - val_categorical_accuracy: 0.5750 - val_loss: 1.2028
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.5512 - loss: 1.2760 - val_categorical_accuracy: 0.6250 - val_loss: 0.9363
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.5941 - loss: 1.1418 - val_categorical_accuracy: 0.6500 - val_loss: 0.8172
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - categorical_accuracy: 0.6669 - loss: 0.8567 - val_categorical_accuracy: 0.7250 - val_loss: 0.6373
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.7046 - loss: 0.7331 - val_categorical_accuracy: 0.8250 - val_loss: 0.5954
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.7639 - loss: 0.5749 - val_categorical_accuracy: 0.6500 - val_loss: 0.7994
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.7985 - loss: 0.5910 - val_categorical_accuracy: 0.9000 - val_loss: 0.3471
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.8534 - loss: 0.4486 - val_categorical_accuracy: 0.8500 - val_loss: 0.3814
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.8348 - loss: 0.4177 - val_categorical_accuracy: 0.8000 - val_loss: 0.3806
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - categorical_accuracy: 0.9085 - loss: 0.2361 - val_categorical_accuracy: 0.9000 - val_loss: 0.2370
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9208 - loss: 0.2367 - val_categorical_accuracy: 0.7500 - val_loss: 0.7101
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.8457 - loss: 0.4021 - val_categorical_accuracy: 0.8500 - val_loss: 0.3681
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9123 - loss: 0.2310 - val_categorical_accuracy: 0.8000 - val_loss: 0.3986
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9108 - loss: 0.2337 - val_categorical_accuracy: 0.7500 - val_loss: 0.8529
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.8409 - loss: 0.5189 - val_categorical_accuracy: 0.7250 - val_loss: 0.8516
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.8928 - loss: 0.2939 - val_categorical_accuracy: 0.8250 - val_loss: 0.4492
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9171 - loss: 0.2224 - val_categorical_accuracy: 0.8500 - val_loss: 0.3544
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - categorical_accuracy: 0.9456 - loss: 0.1319 - val_categorical_accuracy: 0.9000 - val_loss: 0.2310
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - categorical_accuracy: 0.9601 - loss: 0.0932 - val_categorical_accuracy: 0.9500 - val_loss: 0.2007
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9697 - loss: 0.0759 - val_categorical_accuracy: 0.7500 - val_loss: 0.5655
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9486 - loss: 0.1380 - val_categorical_accuracy: 0.9500 - val_loss: 0.2405
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - categorical_accuracy: 0.9567 - loss: 0.1109 - val_categorical_accuracy: 0.9250 - val_loss: 0.1398
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - categorical_accuracy: 0.9607 - loss: 0.1089 - val_categorical_accuracy: 0.9000 - val_loss: 0.2146
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - categorical_accuracy: 0.9641 - loss: 0.1144 - val_categorical_accuracy: 0.9000 - val_loss: 0.2161
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9853 - loss: 0.0526 - val_categorical_accuracy: 0.9000 - val_loss: 0.2772
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9834 - loss: 0.0608 - val_categorical_accuracy: 0.9000 - val_loss: 0.4208
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9778 - loss: 0.0513 - val_categorical_accuracy: 0.9500 - val_loss: 0.2743
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9534 - loss: 0.1358 - val_categorical_accuracy: 0.9250 - val_loss: 0.2163
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - categorical_accuracy: 0.9554 - loss: 0.0947 - val_categorical_accuracy: 0.7500 - val_loss: 0.7558
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9332 - loss: 0.2402 - val_categorical_accuracy: 0.8750 - val_loss: 0.3226
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9609 - loss: 0.1198 - val_categorical_accuracy: 0.8750 - val_loss: 0.2741
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9518 - loss: 0.1344 - val_categorical_accuracy: 0.8250 - val_loss: 0.3787
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9443 - loss: 0.1333 - val_categorical_accuracy: 0.8250 - val_loss: 0.4784
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9678 - loss: 0.0941 - val_categorical_accuracy: 0.9000 - val_loss: 0.2685
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9471 - loss: 0.1110 - val_categorical_accuracy: 0.8250 - val_loss: 0.5296
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9593 - loss: 0.1199 - val_categorical_accuracy: 0.9000 - val_loss: 0.2572
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - categorical_accuracy: 0.9624 - loss: 0.0924 - val_categorical_accuracy: 0.9750 - val_loss: 0.0706
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.9519 - loss: 0.1201 - val_categorical_accuracy: 0.9750 - val_loss: 0.1033
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9596 - loss: 0.1114 - val_categorical_accuracy: 0.9000 - val_loss: 0.2786
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9797 - loss: 0.0395 - val_categorical_accuracy: 0.9500 - val_loss: 0.1690
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9866 - loss: 0.0492 - val_categorical_accuracy: 0.9500 - val_loss: 0.1140
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.9901 - loss: 0.0257 - val_categorical_accuracy: 0.9750 - val_loss: 0.0738
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.9656 - loss: 0.1331 - val_categorical_accuracy: 0.8250 - val_loss: 0.3970
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.9587 - loss: 0.1142 - val_categorical_accuracy: 0.9250 - val_loss: 0.1982
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9861 - loss: 0.0448 - val_categorical_accuracy: 0.9250 - val_loss: 0.2928
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9671 - loss: 0.1088 - val_categorical_accuracy: 0.6250 - val_loss: 1.9474
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.8579 - loss: 0.6170 - val_categorical_accuracy: 0.7750 - val_loss: 0.8142
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.8510 - loss: 0.4301 - val_categorical_accuracy: 0.7500 - val_loss: 0.5341
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - categorical_accuracy: 0.8690 - loss: 0.3842 - val_categorical_accuracy: 0.8250 - val_loss: 0.4884
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9396 - loss: 0.1687 - val_categorical_accuracy: 0.9000 - val_loss: 0.3976
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9609 - loss: 0.1086 - val_categorical_accuracy: 0.8250 - val_loss: 0.3305
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9769 - loss: 0.0430 - val_categorical_accuracy: 0.9000 - val_loss: 0.2592
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9810 - loss: 0.0356 - val_categorical_accuracy: 0.9500 - val_loss: 0.1478
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9869 - loss: 0.0287 - val_categorical_accuracy: 0.9250 - val_loss: 0.2529
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9903 - loss: 0.0283 - val_categorical_accuracy: 0.9000 - val_loss: 0.2184
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9895 - loss: 0.0217 - val_categorical_accuracy: 0.9000 - val_loss: 0.2614
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - categorical_accuracy: 0.9987 - loss: 0.0132 - val_categorical_accuracy: 0.8500 - val_loss: 0.2902
# Model training complete.

# %%
# Prediction
print("Starting prediction...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print("Prediction complete.")
# Out:
# Starting prediction...
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# W0000 00:00:1717257684.506632     152 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# Prediction complete.
# W0000 00:00:1717257685.838859     152 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
# Evaluation
accuracy = accuracy_score(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.975
# F1 Score: 0.9756535947712418

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 5
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# W0000 00:00:1717257702.609980     150 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 2 4 2 7]
# Actual labels (class indices): [3 2 4 2 7]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 8
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 0 3 5 6 6 3 0]
# Actual labels (class indices): [3 0 3 5 6 6 3 0]

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 0 3 5 6 6 3 0]
# Actual labels (class indices): [3 0 3 5 6 6 3 0]

# %%
print("Predicted actions:", predicted_actions)
print("Actual actions:", actual_actions)
# Out:
# Predicted actions: ['ThumbsDown', 'ThumbsUp', 'Stop', 'ThumbsUp', 'Victory']
# Actual actions: ['ThumbsDown', 'ThumbsUp', 'Stop', 'ThumbsUp', 'Victory']
