# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPooling3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

# %%
# Define paths and actions
actions = np.array(['MoveRight', 'MoveLeft', 'ThumbsUp', 'ThumbsDown', 'Stop', 'Circle', 'FistClose', 'Victory'])
data_path = "/kaggle/input/hand-gesture-recogniton/Action_Recognition" 
no_sequences = 100
sequence_length = 60
features = 1662  # Adjust this based on the actual features per frame
num_classes = len(actions)

# %%
print(f"Actions: {actions}")
print(f"Number of classes: {num_classes}")
print(f"Data path: {data_path}")
# Out:
# Actions: ['MoveRight' 'MoveLeft' 'ThumbsUp' 'ThumbsDown' 'Stop' 'Circle'
#  'FistClose' 'Victory']
# Number of classes: 8
# Data path: /kaggle/input/hand-gesture-recogniton/Action_Recognition

# %%
# Map each action to an integer
label_map = {label: num for num, label in enumerate(actions)}
print("Label map:", label_map)
# Out:
# Label map: {'MoveRight': 0, 'MoveLeft': 1, 'ThumbsUp': 2, 'ThumbsDown': 3, 'Stop': 4, 'Circle': 5, 'FistClose': 6, 'Victory': 7}

# %%
# Load data
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame_path = os.path.join(data_path, action, str(sequence), f"{frame_num}.npy")
            res = np.load(frame_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
    print(f"Loaded data for action: {action}")
# Out:
# Loaded data for action: MoveRight
# Loaded data for action: MoveLeft
# Loaded data for action: ThumbsUp
# Loaded data for action: ThumbsDown
# Loaded data for action: Stop
# Loaded data for action: Circle
# Loaded data for action: FistClose
# Loaded data for action: Victory

# %%
# Convert labels to one-hot encoding and lists to numpy arrays
labels = to_categorical(labels, num_classes=num_classes)
sequences = np.array(sequences)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.05, random_state=42)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (760, 60, 1662), X_test shape: (40, 60, 1662)
# y_train shape: (760, 8), y_test shape: (40, 8)

# %%
model = Sequential()

model.add(Reshape((60, 1, 1662, 1), input_shape=(60, 1662, 1)))

# 3D Convolutional layers
model.add(Conv3D(filters=64, kernel_size=(3, 1, 3), activation='relu', padding='same', input_shape=(60, 1, 1662, 1)))
model.add(MaxPooling3D(pool_size=(2, 1, 2)))
model.add(Dropout(0.5))

model.add(Conv3D(filters=64, kernel_size=(3, 1, 3), activation='relu', padding='same'))
model.add(MaxPooling3D(pool_size=(2, 1, 2)))
model.add(Conv3D(filters=128, kernel_size=(3, 1, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(TimeDistributed(Flatten()))

# LSTM layers to capture temporal dependencies
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.5))

# Fully connected layers
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, activation='softmax'))
print("Model has been built.")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model has been built.

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print("Model compilation complete.")
# Out:
# Model compilation complete.

# %%
# Callbacks
tb_callback = TensorBoard(log_dir='./logs', update_freq='batch')
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
print("Callbacks have been set.")
# Out:
# Callbacks have been set.

# %%
# Train the model
print("Starting model training...")
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=100, callbacks=[early_stopping, tb_callback])
print("Model training complete.")
# Out:
# Starting model training...
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 601ms/step - categorical_accuracy: 0.1177 - loss: 2.1171 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.1063
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 351ms/step - categorical_accuracy: 0.1350 - loss: 2.1108 - val_categorical_accuracy: 0.1000 - val_loss: 2.0819
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - categorical_accuracy: 0.1291 - loss: 2.0816 - val_categorical_accuracy: 0.1250 - val_loss: 2.0797
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 349ms/step - categorical_accuracy: 0.1461 - loss: 2.0796 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.0798
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 351ms/step - categorical_accuracy: 0.1304 - loss: 2.0800 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.0803
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - categorical_accuracy: 0.1023 - loss: 2.0788 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.0812
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 358ms/step - categorical_accuracy: 0.1197 - loss: 2.0793 - val_categorical_accuracy: 0.0250 - val_loss: 2.0808
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.1199 - loss: 2.0790 - val_categorical_accuracy: 0.1750 - val_loss: 2.0757
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.1392 - loss: 2.0728 - val_categorical_accuracy: 0.1750 - val_loss: 2.0543
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.1482 - loss: 2.0705 - val_categorical_accuracy: 0.1750 - val_loss: 2.0437
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 383ms/step - categorical_accuracy: 0.2027 - loss: 2.0391 - val_categorical_accuracy: 0.2000 - val_loss: 1.9864
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 384ms/step - categorical_accuracy: 0.1599 - loss: 2.0562 - val_categorical_accuracy: 0.1750 - val_loss: 1.9420
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 378ms/step - categorical_accuracy: 0.2281 - loss: 1.9797 - val_categorical_accuracy: 0.1750 - val_loss: 1.8335
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.2774 - loss: 1.8628 - val_categorical_accuracy: 0.3250 - val_loss: 1.8847
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.2422 - loss: 1.9042 - val_categorical_accuracy: 0.3500 - val_loss: 1.7304
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.3564 - loss: 1.6987 - val_categorical_accuracy: 0.3750 - val_loss: 1.6653
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.4090 - loss: 1.6522 - val_categorical_accuracy: 0.4000 - val_loss: 1.5578
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.4189 - loss: 1.5534 - val_categorical_accuracy: 0.4750 - val_loss: 1.4783
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.4617 - loss: 1.5296 - val_categorical_accuracy: 0.5750 - val_loss: 1.3913
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.4570 - loss: 1.4741 - val_categorical_accuracy: 0.6250 - val_loss: 1.2713
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 371ms/step - categorical_accuracy: 0.4786 - loss: 1.3907 - val_categorical_accuracy: 0.5250 - val_loss: 1.3152
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.5544 - loss: 1.3293 - val_categorical_accuracy: 0.5250 - val_loss: 1.2451
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.5016 - loss: 1.3545 - val_categorical_accuracy: 0.6000 - val_loss: 1.1559
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.5381 - loss: 1.2729 - val_categorical_accuracy: 0.6250 - val_loss: 1.0783
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.5603 - loss: 1.2274 - val_categorical_accuracy: 0.6000 - val_loss: 1.0781
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.5844 - loss: 1.1783 - val_categorical_accuracy: 0.5750 - val_loss: 1.0379
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.6072 - loss: 1.1824 - val_categorical_accuracy: 0.6750 - val_loss: 1.0076
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.5954 - loss: 1.1692 - val_categorical_accuracy: 0.6500 - val_loss: 1.0320
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.5868 - loss: 1.1459 - val_categorical_accuracy: 0.6250 - val_loss: 1.0031
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.6126 - loss: 1.1065 - val_categorical_accuracy: 0.7000 - val_loss: 0.9388
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - categorical_accuracy: 0.6471 - loss: 1.0866 - val_categorical_accuracy: 0.6250 - val_loss: 0.9254
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.6422 - loss: 1.0333 - val_categorical_accuracy: 0.6500 - val_loss: 0.9257
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.6351 - loss: 1.0527 - val_categorical_accuracy: 0.7000 - val_loss: 0.8967
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.5987 - loss: 1.0826 - val_categorical_accuracy: 0.6500 - val_loss: 0.8277
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.6564 - loss: 0.9965 - val_categorical_accuracy: 0.7000 - val_loss: 0.8069
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.6618 - loss: 0.9602 - val_categorical_accuracy: 0.6750 - val_loss: 0.8259
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.6400 - loss: 0.9626 - val_categorical_accuracy: 0.7000 - val_loss: 0.8064
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.6724 - loss: 0.9458 - val_categorical_accuracy: 0.7500 - val_loss: 0.8409
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.6915 - loss: 0.9142 - val_categorical_accuracy: 0.8000 - val_loss: 0.7022
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.6746 - loss: 0.8805 - val_categorical_accuracy: 0.7250 - val_loss: 0.7628
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.6889 - loss: 0.8920 - val_categorical_accuracy: 0.6500 - val_loss: 0.7547
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.6864 - loss: 0.9639 - val_categorical_accuracy: 0.8000 - val_loss: 0.6624
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.7161 - loss: 0.8468 - val_categorical_accuracy: 0.7250 - val_loss: 0.7216
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7196 - loss: 0.8421 - val_categorical_accuracy: 0.7500 - val_loss: 0.7078
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.6331 - loss: 1.0283 - val_categorical_accuracy: 0.7000 - val_loss: 0.7589
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7080 - loss: 0.8462 - val_categorical_accuracy: 0.8250 - val_loss: 0.7255
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7193 - loss: 0.7913 - val_categorical_accuracy: 0.8000 - val_loss: 0.6975
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7387 - loss: 0.8049 - val_categorical_accuracy: 0.6750 - val_loss: 0.8490
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7218 - loss: 0.7952 - val_categorical_accuracy: 0.7000 - val_loss: 0.7850
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7083 - loss: 0.8788 - val_categorical_accuracy: 0.7000 - val_loss: 0.7081
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7195 - loss: 0.8378 - val_categorical_accuracy: 0.7750 - val_loss: 0.6992
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.6973 - loss: 0.8249 - val_categorical_accuracy: 0.6250 - val_loss: 0.7393
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7186 - loss: 0.8127 - val_categorical_accuracy: 0.7000 - val_loss: 0.8490
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7387 - loss: 0.7579 - val_categorical_accuracy: 0.7000 - val_loss: 0.7507
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7464 - loss: 0.7610 - val_categorical_accuracy: 0.8000 - val_loss: 0.6788
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7425 - loss: 0.7248 - val_categorical_accuracy: 0.7500 - val_loss: 0.6845
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.7754 - loss: 0.6984 - val_categorical_accuracy: 0.8250 - val_loss: 0.6458
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.7437 - loss: 0.7749 - val_categorical_accuracy: 0.7750 - val_loss: 0.6788
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7786 - loss: 0.6974 - val_categorical_accuracy: 0.7250 - val_loss: 0.7109
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7569 - loss: 0.6756 - val_categorical_accuracy: 0.6750 - val_loss: 0.6793
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7608 - loss: 0.7092 - val_categorical_accuracy: 0.7000 - val_loss: 0.8025
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7649 - loss: 0.7062 - val_categorical_accuracy: 0.8000 - val_loss: 0.7449
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7756 - loss: 0.6774 - val_categorical_accuracy: 0.8000 - val_loss: 0.7434
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.7709 - loss: 0.6720 - val_categorical_accuracy: 0.8250 - val_loss: 0.6041
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - categorical_accuracy: 0.7790 - loss: 0.6402 - val_categorical_accuracy: 0.7500 - val_loss: 0.7521
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7619 - loss: 0.6818 - val_categorical_accuracy: 0.8000 - val_loss: 0.6681
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7702 - loss: 0.6350 - val_categorical_accuracy: 0.7500 - val_loss: 0.7471
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 369ms/step - categorical_accuracy: 0.7452 - loss: 0.6941 - val_categorical_accuracy: 0.7000 - val_loss: 0.7180
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8062 - loss: 0.6124 - val_categorical_accuracy: 0.8000 - val_loss: 0.6644
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.7481 - loss: 0.7346 - val_categorical_accuracy: 0.7000 - val_loss: 0.7130
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.7958 - loss: 0.5934 - val_categorical_accuracy: 0.8000 - val_loss: 0.6250
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8121 - loss: 0.5280 - val_categorical_accuracy: 0.7500 - val_loss: 0.7273
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.7865 - loss: 0.5867 - val_categorical_accuracy: 0.8250 - val_loss: 0.5927
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.8272 - loss: 0.5139 - val_categorical_accuracy: 0.8000 - val_loss: 0.5743
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8290 - loss: 0.4997 - val_categorical_accuracy: 0.7250 - val_loss: 0.6533
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8284 - loss: 0.5597 - val_categorical_accuracy: 0.8000 - val_loss: 0.6846
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.8369 - loss: 0.5329 - val_categorical_accuracy: 0.8750 - val_loss: 0.5554
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.8247 - loss: 0.5479 - val_categorical_accuracy: 0.7750 - val_loss: 0.7060
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8411 - loss: 0.4828 - val_categorical_accuracy: 0.7500 - val_loss: 0.7163
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8165 - loss: 0.5452 - val_categorical_accuracy: 0.7500 - val_loss: 0.7705
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8465 - loss: 0.4681 - val_categorical_accuracy: 0.8000 - val_loss: 0.7589
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - categorical_accuracy: 0.8429 - loss: 0.4642 - val_categorical_accuracy: 0.8250 - val_loss: 0.5419
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.8783 - loss: 0.4340 - val_categorical_accuracy: 0.8250 - val_loss: 0.6489
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8548 - loss: 0.4555 - val_categorical_accuracy: 0.7750 - val_loss: 0.8204
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8431 - loss: 0.4947 - val_categorical_accuracy: 0.8500 - val_loss: 0.5864
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8734 - loss: 0.4419 - val_categorical_accuracy: 0.8000 - val_loss: 0.5502
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8525 - loss: 0.4478 - val_categorical_accuracy: 0.8000 - val_loss: 0.7087
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8612 - loss: 0.4202 - val_categorical_accuracy: 0.7750 - val_loss: 0.7392
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8692 - loss: 0.4054 - val_categorical_accuracy: 0.8250 - val_loss: 0.5864
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8793 - loss: 0.4331 - val_categorical_accuracy: 0.8250 - val_loss: 0.6316
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - categorical_accuracy: 0.8611 - loss: 0.3880 - val_categorical_accuracy: 0.8250 - val_loss: 0.5225
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - categorical_accuracy: 0.8764 - loss: 0.3997 - val_categorical_accuracy: 0.7500 - val_loss: 0.8596
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8661 - loss: 0.3974 - val_categorical_accuracy: 0.8250 - val_loss: 0.7624
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8449 - loss: 0.4314 - val_categorical_accuracy: 0.8000 - val_loss: 0.6979
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.9105 - loss: 0.3483 - val_categorical_accuracy: 0.7750 - val_loss: 0.6513
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8723 - loss: 0.4072 - val_categorical_accuracy: 0.7500 - val_loss: 0.8284
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.9090 - loss: 0.3374 - val_categorical_accuracy: 0.7750 - val_loss: 0.7476
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.8957 - loss: 0.3636 - val_categorical_accuracy: 0.7750 - val_loss: 0.6773
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - categorical_accuracy: 0.9165 - loss: 0.3159 - val_categorical_accuracy: 0.7750 - val_loss: 0.7168
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - categorical_accuracy: 0.8662 - loss: 0.4253 - val_categorical_accuracy: 0.8000 - val_loss: 0.8066
# Model training complete.

# %%
# Prediction
print("Starting prediction...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print("Prediction complete.")
# Out:
# Starting prediction...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step
# Prediction complete.

# %%
# Evaluation
accuracy = accuracy_score(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.825
# F1 Score: 0.8248319327731093

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 5
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 3 0 4 7]
# Actual labels (class indices): [7 3 0 4 7]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 8
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [3 3 4 2 3 0 6 6]
# Actual labels (class indices): [7 3 6 2 2 0 6 6]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
print("Predicted actions:", predicted_actions)
print("Actual actions:", actual_actions)
# Out:
# Predicted actions: ['ThumbsDown', 'ThumbsDown', 'Stop', 'ThumbsUp', 'ThumbsDown', 'MoveRight', 'FistClose', 'FistClose']
# Actual actions: ['Victory', 'ThumbsDown', 'FistClose', 'ThumbsUp', 'ThumbsUp', 'MoveRight', 'FistClose', 'FistClose']
