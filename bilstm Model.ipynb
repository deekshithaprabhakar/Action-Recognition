# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
# Out:
# 2024-06-01 09:18:17.357618: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-01 09:18:17.357747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-01 09:18:17.495533: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Define paths and actions
actions = np.array(['MoveRight', 'MoveLeft', 'ThumbsUp', 'ThumbsDown', 'Stop', 'Circle', 'FistClose', 'Victory'])
data_path = "/kaggle/input/hand-gesture-recogniton/Action_Recognition" 
no_sequences = 100
sequence_length = 60
features = 1662  # Adjust this based on the actual features per frame
num_classes = len(actions)

# %%
print(f"Actions: {actions}")
print(f"Number of classes: {num_classes}")
print(f"Data path: {data_path}")
# Out:
# Actions: ['MoveRight' 'MoveLeft' 'ThumbsUp' 'ThumbsDown' 'Stop' 'Circle'
#  'FistClose' 'Victory']
# Number of classes: 8
# Data path: /kaggle/input/hand-gesture-recogniton/Action_Recognition

# %%
# Map each action to an integer
label_map = {label: num for num, label in enumerate(actions)}
print("Label map:", label_map)
# Out:
# Label map: {'MoveRight': 0, 'MoveLeft': 1, 'ThumbsUp': 2, 'ThumbsDown': 3, 'Stop': 4, 'Circle': 5, 'FistClose': 6, 'Victory': 7}

# %%
# Load data
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame_path = os.path.join(data_path, action, str(sequence), f"{frame_num}.npy")
            res = np.load(frame_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
    print(f"Loaded data for action: {action}")
# Out:
# Loaded data for action: MoveRight
# Loaded data for action: MoveLeft
# Loaded data for action: ThumbsUp
# Loaded data for action: ThumbsDown
# Loaded data for action: Stop
# Loaded data for action: Circle
# Loaded data for action: FistClose
# Loaded data for action: Victory

# %%
# Convert labels to one-hot encoding and lists to numpy arrays
labels = to_categorical(labels, num_classes=num_classes)
sequences = np.array(sequences)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.05, random_state=42)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (760, 60, 1662), X_test shape: (40, 60, 1662)
# y_train shape: (760, 8), y_test shape: (40, 8)

# %%
# Build the model
model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True), input_shape=(sequence_length, features)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])
print("Model has been built.")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model has been built.

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print("Model compilation complete.")
# Out:
# Model compilation complete.

# %%
# Callbacks
tb_callback = TensorBoard(log_dir='./logs', update_freq='batch')
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
print("Callbacks have been set.")
# Out:
# Callbacks have been set.

# %%
# Train the model
print("Starting model training...")
model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=200, callbacks=[early_stopping, tb_callback])
print("Model training complete.")
# Out:
# Starting model training...
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - categorical_accuracy: 0.1190 - loss: 2.1014 - val_categorical_accuracy: 0.0500 - val_loss: 2.0910
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1114 - loss: 2.0874 - val_categorical_accuracy: 0.1750 - val_loss: 2.0849
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1088 - loss: 2.0844 - val_categorical_accuracy: 0.1000 - val_loss: 2.0759
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1474 - loss: 2.0797 - val_categorical_accuracy: 0.1000 - val_loss: 2.0810
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1319 - loss: 2.0762 - val_categorical_accuracy: 0.1000 - val_loss: 2.0623
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1424 - loss: 2.0687 - val_categorical_accuracy: 0.1000 - val_loss: 2.0578
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1399 - loss: 2.0635 - val_categorical_accuracy: 0.1000 - val_loss: 2.0279
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.1640 - loss: 2.0560 - val_categorical_accuracy: 0.3500 - val_loss: 2.0002
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.1819 - loss: 2.0171 - val_categorical_accuracy: 0.2500 - val_loss: 1.9382
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1664 - loss: 1.9933 - val_categorical_accuracy: 0.2000 - val_loss: 1.8281
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1805 - loss: 1.9739 - val_categorical_accuracy: 0.2000 - val_loss: 1.9402
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2127 - loss: 1.9548 - val_categorical_accuracy: 0.2250 - val_loss: 1.7945
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2716 - loss: 1.8854 - val_categorical_accuracy: 0.2500 - val_loss: 1.9780
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1932 - loss: 1.9315 - val_categorical_accuracy: 0.3000 - val_loss: 1.7767
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2533 - loss: 1.8401 - val_categorical_accuracy: 0.3000 - val_loss: 1.7015
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2294 - loss: 1.8834 - val_categorical_accuracy: 0.3250 - val_loss: 1.7650
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2357 - loss: 1.8554 - val_categorical_accuracy: 0.3250 - val_loss: 1.7082
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2612 - loss: 1.8049 - val_categorical_accuracy: 0.2250 - val_loss: 1.7626
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2598 - loss: 1.8229 - val_categorical_accuracy: 0.2500 - val_loss: 1.7340
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2696 - loss: 1.8346 - val_categorical_accuracy: 0.2750 - val_loss: 1.7748
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2759 - loss: 1.7938 - val_categorical_accuracy: 0.2000 - val_loss: 1.7365
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2536 - loss: 1.8705 - val_categorical_accuracy: 0.2500 - val_loss: 1.8020
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3032 - loss: 1.7533 - val_categorical_accuracy: 0.3750 - val_loss: 1.6338
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2919 - loss: 1.7284 - val_categorical_accuracy: 0.3250 - val_loss: 1.6828
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3464 - loss: 1.7164 - val_categorical_accuracy: 0.3750 - val_loss: 1.5886
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3418 - loss: 1.6780 - val_categorical_accuracy: 0.3500 - val_loss: 1.6015
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3470 - loss: 1.7253 - val_categorical_accuracy: 0.3250 - val_loss: 1.6345
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3437 - loss: 1.6888 - val_categorical_accuracy: 0.3000 - val_loss: 1.6129
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3301 - loss: 1.6896 - val_categorical_accuracy: 0.3000 - val_loss: 1.7548
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3876 - loss: 1.6826 - val_categorical_accuracy: 0.3500 - val_loss: 1.5595
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - categorical_accuracy: 0.3347 - loss: 1.6778 - val_categorical_accuracy: 0.2750 - val_loss: 1.5530
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3092 - loss: 1.6372 - val_categorical_accuracy: 0.3750 - val_loss: 1.5381
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.3252 - loss: 1.6385 - val_categorical_accuracy: 0.3750 - val_loss: 1.5526
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3636 - loss: 1.6594 - val_categorical_accuracy: 0.2250 - val_loss: 1.7099
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - categorical_accuracy: 0.2955 - loss: 1.7916 - val_categorical_accuracy: 0.3500 - val_loss: 1.5459
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - categorical_accuracy: 0.3551 - loss: 1.6500 - val_categorical_accuracy: 0.4000 - val_loss: 1.5108
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3424 - loss: 1.6170 - val_categorical_accuracy: 0.4000 - val_loss: 1.4928
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - categorical_accuracy: 0.3437 - loss: 1.6659 - val_categorical_accuracy: 0.4250 - val_loss: 1.4885
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.7115 - loss: 0.7749 - val_categorical_accuracy: 0.8250 - val_loss: 0.5559
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.7146 - loss: 0.7158 - val_categorical_accuracy: 0.8000 - val_loss: 0.6118
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.6838 - loss: 0.8346 - val_categorical_accuracy: 0.8000 - val_loss: 0.6026
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.7249 - loss: 0.6873 - val_categorical_accuracy: 0.7500 - val_loss: 0.5803
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.7046 - loss: 0.7777 - val_categorical_accuracy: 0.7500 - val_loss: 0.7510
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.6862 - loss: 0.8075 - val_categorical_accuracy: 0.8000 - val_loss: 0.5500
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.6871 - loss: 0.7908 - val_categorical_accuracy: 0.7750 - val_loss: 0.5857
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.6969 - loss: 0.7538 - val_categorical_accuracy: 0.7500 - val_loss: 0.5632
# Model training complete.

# %%
# Prediction
print("Starting prediction...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print("Prediction complete.")
# Out:
# Starting prediction...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step
# Prediction complete.

# %%
# Evaluation
accuracy = accuracy_score(y_true, y_pred_classes)
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.825
# F1 Score: 0.8251785714285715

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 5
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [0 0 2 3 4]
# Actual labels (class indices): [0 0 7 3 4]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
# Selecting a few samples (e.g., 5 samples) from the test set for prediction
num_samples_to_predict = 8
sample_indices = np.random.choice(X_test.shape[0], num_samples_to_predict, replace=False)  # Randomly pick indices without replacement
sample_data = X_test[sample_indices]
sample_labels = y_test[sample_indices]

# %%
# Make predictions
sample_predictions = model.predict(sample_data)
sample_pred_classes = np.argmax(sample_predictions, axis=1)
sample_true_classes = np.argmax(sample_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# Print the results
print("Sample predictions (class indices):", sample_pred_classes)
print("Actual labels (class indices):", sample_true_classes)
# Out:
# Sample predictions (class indices): [5 4 4 5 5 0 3 0]
# Actual labels (class indices): [5 6 4 5 5 0 3 0]

# %%
# Map indices back to action names for clearer interpretation
predicted_actions = [actions[idx] for idx in sample_pred_classes]
actual_actions = [actions[idx] for idx in sample_true_classes]

# %%
print("Predicted actions:", predicted_actions)
print("Actual actions:", actual_actions)
# Out:
# Predicted actions: ['Circle', 'Stop', 'Stop', 'Circle', 'Circle', 'MoveRight', 'ThumbsDown', 'MoveRight']
# Actual actions: ['Circle', 'FistClose', 'Stop', 'Circle', 'Circle', 'MoveRight', 'ThumbsDown', 'MoveRight']
